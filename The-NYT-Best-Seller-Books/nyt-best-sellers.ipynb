# %% [markdown]
# ## Scraping The New York Times Best Sellers Books

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime, timedelta
import json
import threading

# %% [markdown]
# ## Book class

# %%
class Book:
    def __init__(self, title, img_url, position, description):
        self.title = title
        self.img_url = img_url
        self.position = position
        self.description = description

    @property
    def title(self):
        return self._title

    @title.setter
    def title(self, title):
        self._title = title

    @property
    def img_url(self):
        return self._img_url

    @img_url.setter
    def img_url(self, img_url):
        self._img_url = img_url

    @property
    def position(self):
        return self._position

    @position.setter
    def position(self, position):
        self._position = position

    @property
    def description(self):
        return self._description

    @description.setter
    def description(self, description):
        self._description = description
    
    def __str__(self):
        book_dict = {}
        book_dict["title"] = self.title
        book_dict["img_url"] = self.img_url
        book_dict["position"] = self.position
        book_dict["description"] = self.description
        return json.dumps(book_dict)

# %% [markdown]
# ## Category class

# %%
class Category:
    def __init__(self, name, best_sellers_books):
        self.name = name
        self.best_sellers_books = best_sellers_books

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, name):
        self._name = name

    @property
    def best_sellers_books(self):
        return self._best_sellers_books

    @best_sellers_books.setter
    def best_sellers_books(self, best_sellers_books):
        self._best_sellers_books = best_sellers_books

    def __str__(self):
        books_formt = '[\n'
        for book in self.best_sellers_books:
            books_formt += '\t'
            books_formt += f'{book}'
            books_formt += ',\n'
        books_formt= books_formt[:-2]
        books_formt += '\n]'
        return f'"category": "{self.name}",\nbooks:{books_formt}'

# %% [markdown]
# ## Week class

# %%
class Week:
    def __init__(self, number, categories):
        self.number = number
        self.categories = categories

    @property
    def number(self):
        return self._number

    @number.setter
    def number(self, number):
        self._number = number

    @property
    def categories(self):
        return self._categories

    @categories.setter
    def categories(self, categories):
        self._categories = categories

    @staticmethod
    def get_dict(self):
        week_dict = {}
        week_dict["week"] = self.number
        week_dict["data"] = self.categories
        return week_dict
        
    def __str__(self):
        output = '[{\n'
        for category in self.categories:
            output += f'{category}'
            output += ',\n\n'
        output= output[:-3]
        output += '\n}]'
        return '{' + f'"week": "{self.number}", "data":{output}' + '}'

# %% [markdown]
# ## Utils funcs

# %%
def adjustDateFormation(date):
    """
    :param date: datetime object
    :return: modified string version of an datetime object 
    """ 
    return str(date).replace('-','/')

# %%
def get_past_weeks_dates(initial_date, number_of_weeks):
    """
    :param initial_date: datetime object of the current week date
    :param number_of_weeks: number of weeks to go back to
    :return: list of all the past weeks dates
    """ 
    week_dates_list = ['']
    prev_week_date = initial_date
    
    for i in range(number_of_weeks - 1):
        prev_week_date = prev_week_date - timedelta(days=7)
        week_dates_list.append(prev_week_date.date())

    # modify date to yyyy/mm/dd format
    modified_week_dates_list = list(map(adjustDateFormation, week_dates_list))
        
    return modified_week_dates_list

# %%
def parse_categories(soup_categories):
    """
    :param soup_categories: a bs4 object that contains all the categories names
    :return: list of all the categories names in order of appearnce
    """ 
    categories_names = []
    
    for row in soup_categories:
        str_row = str(row).replace('amp;','')
        parse_mid = str_row.split('>')[1]
        category_name = parse_mid.split('<')[0]
        categories_names.append(category_name)
    return categories_names

# %%
def parse_books(soup_books):
    """
    :param soup_books: a bs4 object that contains all the books & their data
    :return: list of all the best sellers books in order of appearnce, as Book objects 
    """ 
    books = []

    for i in range(len(soup_books)):
        str_row = str(soup_books[i])
        
        img_url = str_row.split('src="')[1].split('"/>')[0]
        title = str_row.split('"name">')[1].split('</h3>')[0]
        description = str_row.split('"description">')[1].split('</p>')[0].replace('\u201c','').replace('\u201d', '')
        position = (i % 5) + 1
        
        book = Book(title=title, img_url=img_url, position=position, description=description)
        books.append(book)
        
    return books

# %%
def match_books_to_categories(categories_names, books):
    """
    :param categories_names: a list of all the categories names in order of appearnce 
    :param books: list of all the best sellers books in order of appearnce as Book objects
    :return: list of all the categories and their best sellers books, as Category objects
    """ 
    categories = []
    
    for i in range(0, len(books), books_per_category):
        category_index = int(i / books_per_category)
        category_name = categories_names[category_index]
        
        first_book_index = i
        last_book_index = i + books_per_category

        category_books = books[first_book_index : last_book_index]
        category = Category(name=category_name , best_sellers_books=category_books)

        categories.append(category)

    return categories

# %%
def modify_week_format(raw_week_date):
    """
    :param raw_week_date: string date of: "month date, year" format
    :return: datetime object of the week's date
    """ 
    
    month_dict = {'January':'1', 'February':'2', 'March':'3' , 'April':'4',
                  'May':'5', 'June':'6', 'July':'7', 'August':'8',
                  'September':'9', 'October':'10', 'November':'11', 'December':'12'}

    filtered = raw_week_date.split('>')[1].replace(',', '')
    month = month_dict.get(filtered.split(' ')[0])
    day = filtered.split(' ')[1]
    year = filtered.split('<')[0][-4:]
    str_date = f'{year}/{month}/{day}'
    return datetime.strptime(str_date, '%Y/%m/%d')

# %%
def get_urls_to_scrape(soup, url, number_of_weeks):
    """
    :param soup: a bs4 object of the url's raw data
    :param url: the web page url
    :param number_of_weeks: number of weeks to go back to
    :return: list that contains the web page's url for each past week 
    """ 
    # Locate initial week in the homepage
    raw_initial_week = soup.find('time', {"class": "css-6068ga"})
    initial_week = modify_week_format(str(raw_initial_week))
    
    # Create a list of the dates of all past weeks
    past_weeks_dates_list = get_past_weeks_dates(initial_date=initial_week, number_of_weeks=number_of_weeks)
    
    # Create a list of all the urls
    urls_to_scrape = [url + week_date for week_date in past_weeks_dates_list]
    
    return urls_to_scrape

# %%
def scrape_url(url, week_id):
    """
    :param url: the url of the desired web page to scrape
    :param week_id: the index of the week's inside the url (the latest week id would be 144)
    :return: saves the url's data inside the week_id index of the output list
    """ 
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "lxml")
    
    # Create a list of the categories names 
    soup_categories = soup.findAll('a', {"class": "css-nzgijy"})
    categories_names = parse_categories(soup_categories)
    
    # Create a list of all the best selling book as Book objects
    soup_books = soup.findAll('a', {"class": "css-g5yn3w"})
    books = parse_books(soup_books)
    
    # Create a list of all the categories as Category objects
    categories = match_books_to_categories(categories_names, books)
    
    # Create a week object
    week = Week(number=number_of_weeks-week_id, categories=categories)

    best_sellers[week_id] = week
    return

# %% [markdown]
# ## Main

# %%
url = 'https://www.nytimes.com/books/best-sellers/'
r = requests.get(url)
soup = BeautifulSoup(r.content, "lxml")

# %%
# Set number of weeks:
number_of_weeks = 144

# %%
# Set number of best sellers per category:
books_per_category = 5

# %%
# Create a list of urls to scrape by matching a url to each week:
urls = get_urls_to_scrape(soup, url, number_of_weeks)

# %%
# Declare a variable to contain the final output
best_sellers = [None] * number_of_weeks

# %%
# Declare a threads list to support an efficient multiproccening solution
threads = []

# %%
# Divide the scraping task between multiple threads
for i in reversed(range(number_of_weeks)):
    t = threading.Thread(target=scrape_url, args=(urls[i],i))
    threads.append(t)
    t.start()

for t in threads:
    t.join()

# %%
print(best_sellers[0])
# Out:
# {"week": "144", "data":[{
# "category": "Combined Print & E-Book Fiction",
# books:[
# 	{"title": "FOURTH WING", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781649374042.jpg", "position": 1, "description": "Violet Sorrengail is urged by the commanding general, who also is her mother, to become a candidate for the elite dragon riders."},
# 	{"title": "BLOOD LINES", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781501101816.jpg", "position": 2, "description": "The second book in the Scott Brodie and Maggie Taylor series. After a mission in Venezuela, Brodie and Taylor search for the murderer of a fellow agent."},
# 	{"title": "WILDFIRE", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781668026274.jpg", "position": 3, "description": "The second book in the Maple Hills series. Two summer camp counselors who previously had a one-night stand may run afoul of the camp\u2019s rules."},
# 	{"title": "LESSONS IN CHEMISTRY", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780385547345.jpg", "position": 4, "description": "A scientist and single mother living in California in the 1960s becomes a star on a TV cooking show."},
# 	{"title": "JUDGMENT PREY", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780593542811.jpg", "position": 5, "description": "The 33rd book in the Prey series. Davenport and Flowers investigate the murder of a federal judge and his two young sons."}
# ],
#
# "category": "Combined Print & E-Book Nonfiction",
# books:[
# 	{"title": "KILLERS OF THE FLOWER MOON", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780385534246.jpg", "position": 1, "description": "The story of a murder spree in 1920s Oklahoma that targeted Osage Indians, whose lands contained oil."},
# 	{"title": "ENOUGH", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781668028285.jpg", "position": 2, "description": "The former special assistant to President Trump and his chief of staff, Mark Meadows, details events surrounding the crisis of conscience she faced."},
# 	{"title": "ELON MUSK", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781982181284.jpg", "position": 3, "description": "The author of The Code Breaker traces Musk\u2019s life and summarizes his work on electric vehicles, private space exploration and artificial intelligence."},
# 	{"title": "KILLING THE WITCHES", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781250283320.jpg", "position": 4, "description": "The 13th book in the conservative commentator\u2019s Killing series gives a portrayal of the events of 1692 and 1693 in Salem Village, Mass."},
# 	{"title": "GOING INFINITE", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781324074335.jpg", "position": 5, "description": "The author of The Big Short and The Premonition chronicles the rise and fall of Sam Bankman-Fried and FTX."}
# ],
#
# "category": "Hardcover Fiction",
# books:[
# 	{"title": "FOURTH WING", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781649374042.jpg", "position": 1, "description": "Violet Sorrengail is urged by the commanding general, who also is her mother, to become a candidate for the elite dragon riders."},
# 	{"title": "LESSONS IN CHEMISTRY", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780385547345.jpg", "position": 2, "description": "A scientist and single mother living in California in the 1960s becomes a star on a TV cooking show."},
# 	{"title": "HOLLY", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781668016138.jpg", "position": 3, "description": "The private detective Holly Gibney investigates whether a married pair of octogenarian academics had anything to do with Bonnie Dahl\u2019s disappearance."},
# 	{"title": "SWORD CATCHER", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780525619994.jpg", "position": 4, "description": "An orphan who is the body double for a royal heir and a woman with magical abilities are drawn into the underworld of the city-state of Castellane."},
# 	{"title": "BLOOD LINES", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781501101816.jpg", "position": 5, "description": "The second book in the Scott Brodie and Maggie Taylor series. After a mission in Venezuela, Brodie and Taylor search for the murderer of a fellow agent."}
# ],
#
# "category": "Hardcover Nonfiction",
# books:[
# 	{"title": "ENOUGH", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781668028285.jpg", "position": 1, "description": "The former special assistant to President Trump and his chief of staff, Mark Meadows, details events surrounding the crisis of conscience she faced."},
# 	{"title": "ELON MUSK", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781982181284.jpg", "position": 2, "description": "The author of The Code Breaker traces Musk\u2019s life and summarizes his work on electric vehicles, private space exploration and artificial intelligence."},
# 	{"title": "KILLING THE WITCHES", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781250283320.jpg", "position": 3, "description": "The 13th book in the conservative commentator\u2019s Killing series gives a portrayal of the events of 1692 and 1693 in Salem Village, Mass."},
# 	{"title": "TO RESCUE THE CONSTITUTION", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780063039582.jpg", "position": 4, "description": "The chief political anchor for Fox News gives an account of important actions taken by George Washington."},
# 	{"title": "THE DEMOCRAT PARTY HATES AMERICA", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781501183157.jpg", "position": 5, "description": "The Fox News host and author of American Marxism argues for the defeat of the Democratic Party."}
# ],
#
# "category": "Paperback Trade Fiction",
# books:[
# 	{"title": "WILDFIRE", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781668026274.jpg", "position": 1, "description": "The second book in the Maple Hills series. Two summer camp counselors who previously had a one-night stand may run afoul of the camp\u2019s rules."},
# 	{"title": "ICEBREAKER", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781668026038.jpg", "position": 2, "description": "Anastasia might need the help of the captain of a college hockey team to get on the Olympic figure skating team."},
# 	{"title": "TWISTED LOVE", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781728274867.jpg", "position": 3, "description": "The first book in the Twisted series. Secrets emerge when Ava explores things with her brother\u2019s best friend."},
# 	{"title": "THE SEVEN HUSBANDS OF EVELYN HUGO", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781501161933.jpg", "position": 4, "description": "A movie icon recounts stories of her loves and career to a struggling magazine writer."},
# 	{"title": "THINGS WE LEFT BEHIND", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781728276120.jpg", "position": 5, "description": "The third book in the Knockemout series. A mogul and a small-town librarian share a dark secret from their past."}
# ],
#
# "category": "Paperback Nonfiction",
# books:[
# 	{"title": "KILLERS OF THE FLOWER MOON", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780385534246.jpg", "position": 1, "description": "The story of a murder spree in 1920s Oklahoma that targeted Osage Indians, whose lands contained oil. The fledgling F.B.I. intervened, ineffectively."},
# 	{"title": "THE BODY KEEPS THE SCORE", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780670785933.jpg", "position": 2, "description": "How trauma affects the body and mind, and innovative treatments for recovery."},
# 	{"title": "CRYING IN H MART", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780525657743.jpg", "position": 3, "description": "The daughter of a Korean mother and Jewish American father, and leader of the indie rock project Japanese Breakfast, describes creating her own identity after losing her mother to cancer."},
# 	{"title": "BRAIDING SWEETGRASS", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781571313560.jpg", "position": 4, "description": "A botanist and member of the Citizen Potawatomi Nation espouses having an understanding and appreciation of plants and animals."},
# 	{"title": "THINKING, FAST AND SLOW", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781429969352.jpg", "position": 5, "description": "When we can and cannot trust our intuitions in making business and personal decisions."}
# ],
#
# "category": "Advice, How-To & Miscellaneous",
# books:[
# 	{"title": "BE USEFUL", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780593655955.jpg", "position": 1, "description": ""},
# 	{"title": "THE WAY FORWARD", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781524874834.jpg", "position": 2, "description": ""},
# 	{"title": "NOT THAT FANCY", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781400238255.jpg", "position": 3, "description": ""},
# 	{"title": "ATOMIC HABITS", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780735211292.jpg", "position": 4, "description": ""},
# 	{"title": "MORE IS MORE", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780593578841.jpg", "position": 5, "description": ""}
# ],
#
# "category": "Children’s Middle Grade Hardcover",
# books:[
# 	{"title": "THE HARRY POTTER WIZARDING ALMANAC", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781339018140.jpg", "position": 1, "description": "An official companion to the seven Harry Potter novels."},
# 	{"title": "THE PUPPETS OF SPELHORST", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781536216752.jpg", "position": 2, "description": "The first of the Norendy Tales series relates the misadventures of five puppets."},
# 	{"title": "WINGS OF FIRE: A GUIDE TO THE DRAGON WORLD", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781338634822.jpg", "position": 3, "description": "A deeper dive into the legends of the 10 dragon tribes."},
# 	{"title": "THE SUN AND THE STAR", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781368081153.jpg", "position": 4, "description": "The demigods Will and Nico embark on a dangerous journey to the Underworld to rescue an old friend."},
# 	{"title": "THE OFFICIAL HARRY POTTER COOKBOOK", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781338893076.jpg", "position": 5, "description": "Forty plus recipes inspired by the films."}
# ],
#
# "category": "Children’s Picture Books",
# books:[
# 	{"title": "JUST BECAUSE", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780593622032.jpg", "position": 1, "description": "Wisdom about life\u2019s contradictions."},
# 	{"title": "ZILOT AND OTHER IMPORTANT RHYMES", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780316438506.jpg", "position": 2, "description": "A compilation of silly poems."},
# 	{"title": "THE LEAF THIEF", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781728269894.jpg", "position": 3, "description": "Squirrel attempts to figure out who has stolen his leaves."},
# 	{"title": "HOW TO CATCH A WITCH", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781728210353.jpg", "position": 4, "description": "The Catch Club Kids attempt to snare a witch on Halloween."},
# 	{"title": "HOW TO CATCH A MONSTER", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781492648949.jpg", "position": 5, "description": "A boy attempts to catch the monster in his closet."}
# ],
#
# "category": "Children’s Series",
# books:[
# 	{"title": "HARRY POTTER", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780590353427.jpg", "position": 1, "description": "A wizard hones his conjuring skills in the service of fighting evil."},
# 	{"title": "PERCY JACKSON &amp; THE OLYMPIANS", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781423131892.jpg", "position": 2, "description": "A boy battles mythological monsters."},
# 	{"title": "DIARY OF A WIMPY KID", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781419711329.jpg", "position": 3, "description": "The travails and challenges of adolescence."},
# 	{"title": "THE HUNGER GAMES", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780545663267.jpg", "position": 4, "description": "In a dystopia, a girl fights for survival on live TV."},
# 	{"title": "A GOOD GIRL'S GUIDE TO MURDER", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780593379851.jpg", "position": 5, "description": "Pippa Fitz-Amobi solves murderous crimes."}
# ],
#
# "category": "Young Adult Hardcover",
# books:[
# 	{"title": "DIVINE RIVALS", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781250857439.jpg", "position": 1, "description": "Two young rival journalists find love through a magical connection."},
# 	{"title": "CURIOUS TIDES", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781665957328.jpg", "position": 2, "description": "Emory develops new magical powers after a ritual gone awry leaves some of her friends drowned in a forbidden cave."},
# 	{"title": "NIGHT OF THE WITCH", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781728272160.jpg", "position": 3, "description": "Otto, working undercover among witch hunters, and Fritzi, a witch, must work together to vanquish a common enemy."},
# 	{"title": "THIS WINTER", "img_url": "https://storage.googleapis.com/du-prd/books/images/9781338885132.jpg", "position": 4, "description": "Siblings Tori, Charlie and Oliver deal with life challenges over the holiday season."},
# 	{"title": "A STUDY IN DROWNING", "img_url": "https://storage.googleapis.com/du-prd/books/images/9780063211506.jpg", "position": 5, "description": "Dark forces try to thwart Preston and Effy's efforts to unravel the mysteries of author Emrys Myrddin's Hiraeth Manor."}
# ]
# }]}
